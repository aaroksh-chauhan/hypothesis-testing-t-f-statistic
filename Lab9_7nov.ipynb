# %% [markdown]
# # NAME - AAROKSH CHAUHAN
# # ROLL NO. 25CL05014

# %%
import xarray as xr

pt = "C:/Users/user/Desktop/Aaroksh/HadlSST/HadISST_sst.nc"
ds = xr.open_dataset(pt)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1868, nv: 2, latitude: 180, longitude: 360)
# Coordinates:
#   * time       (time) datetime64[ns] 1870-01-16T11:59:59.505615234 ... 2025-0...
#   * latitude   (latitude) float32 89.5 88.5 87.5 86.5 ... -87.5 -88.5 -89.5
#   * longitude  (longitude) float32 -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds  (time, nv) float32 ...
#     sst        (time, latitude, longitude) float32 ...
# Attributes:
#     Title:                      Monthly version of HadISST sea surface temper...
#     description:                HadISST 1.1 monthly average sea surface tempe...
#     institution:                Met Office Hadley Centre
#     source:                     HadISST
#     reference:                  Rayner, N. A., Parker, D. E., Horton, E. B., ...
#     Conventions:                CF-1.0
#     history:                    6/10/2025 converted to netcdf from pp format
#     supplementary_information:  Updates and supplementary information will be...
#     comment:                    Data restrictions: for academic research use ...

# %% [markdown]
# **GENERATING THE RANDOM 360 STEPS , 1000 TIMES**

# %%
import numpy as np
import random
SST = ds["sst"]
np.random.seed(42)                                                 # DOING THIS WILL NOT CHANGE THE OUTCOMES GENERATED
regional_sst = SST.sel(latitude=slice(5,-5), longitude=slice(-170,-120))    # SELECTING THE LAT , LONG OF NINO 3.4 AREA 
areal_mean = regional_sst.mean(dim = ['latitude','longitude'])              # CALCULATING THE AREAL MEAN   

times = areal_mean.sizes['time']                                            # CALCULATING THE SIZE OF TIME STEPS
print('The total no of time steps is',times)
a =1000
num_data = np.zeros([a,1])         #Creating an array using np.zeros 
for i in range(a):
    rand_steps = np.random.choice(areal_mean,360,replace=False)             # PICKING UP RANDOM 360 NON REPEATING STEPS OUT OF TOTAL 1868 STEPS
    num_data[i] = np.mean(rand_steps)                                       # STORING THESE VALUES INTO THE ALREADY CREATED EMPTY ARRAY
   
print(num_data)
# Out:
# The total no of time steps is 1868
# [[26.92771339]
#  [27.01779175]
#  [26.89641571]
#  [26.9800148 ]
#  [26.91564178]
#  [26.96912956]
#  [26.87599754]
#  [26.95723152]
#  [26.93637657]
#  [26.97532845]
#  [26.94895744]
#  [26.9576664 ]
#  [26.96571732]
#  [26.95825195]
#  [26.92118263]
#  [26.9200325 ]
#  [26.88901901]
#  [26.95154953]
#  [26.96037292]
#  [26.87056732]
#  [26.91941643]
#  [26.97183418]
#  [26.89142227]
#  [26.929842  ]
#  [26.93656158]
#  [26.99280357]
#  [26.99769402]
#  [26.87460327]
#  [27.00704193]
#  [26.88714981]
#  [26.98797226]
#  [26.91181183]
#  [26.99176407]
#  [26.95124245]
#  [26.9133091 ]
#  [26.99916458]
#  [26.90837669]
#  [26.90216255]
#  [26.95340347]
#  [27.01827812]
#  [26.90244102]
#  [26.90486908]
#  [26.93165779]
#  [26.91933632]
#  [26.97871017]
#  [26.97779465]
#  [26.9712677 ]
#  [26.90144348]
#  [26.91669464]
#  [26.98950768]
#  [26.95250702]
#  [26.91965103]
#  [26.88360977]
#  [26.90148735]
#  [26.93626022]
#  [26.86970139]
#  [26.94680405]
#  [26.98148918]
#  [26.98435402]
#  [26.94565392]
#  [26.97055626]
#  [26.97468567]
#  [26.96427345]
#  [26.90218163]
#  [26.94177818]
#  [26.87730026]
#  [26.95892143]
#  [26.95687103]
#  [26.94677544]
#  [26.90634537]
#  [26.94569588]
#  [26.93695259]
#  [26.93650627]
#  [26.97421265]
#  [26.88888359]
#  [26.79523087]
#  [26.89185333]
#  [26.97018242]
#  [26.94886017]
#  [26.9413681 ]
#  [26.9812603 ]
#  [26.94285393]
#  [26.93496704]
#  [26.93717384]
#  [27.00120354]
#  [26.96362495]
#  [26.93565559]
#  [26.8884716 ]
#  [26.9138298 ]
#  [26.98648453]
#  [26.92902565]
#  [26.95939064]
#  [26.93622017]
#  [26.90069962]
#  [26.91303635]
#  [26.90806389]
#  [26.92827606]
#  [26.96985054]
#  [26.86506653]
#  [26.95525169]
#  [26.9484272 ]
#  [26.86776352]
#  [26.92305183]
#  [26.95487785]
#  [26.96520805]
#  [26.8957119 ]
#  [26.90605927]
#  [26.91620064]
#  [26.97004318]
#  [26.96196747]
#  [26.93302727]
#  [26.90328598]
#  [26.91205788]
#  [26.95960236]
#  [26.91143417]
#  [26.96002007]
#  [26.90271568]
#  [27.01750755]
#  [26.91540527]
#  [26.99543762]
#  [26.91169167]
#  [26.9174633 ]
#  [26.89076614]
#  [26.91979218]
#  [26.88103867]
#  [26.97533035]
#  [26.95488739]
#  [26.91160774]
#  [26.93116951]
#  [26.98624039]
#  [26.97888184]
#  [26.95393372]
#  [26.91939926]
#  [26.88656616]
#  [26.90678978]
#  [26.9004879 ]
#  [26.98498344]
#  [26.91183853]
#  [26.86418152]
#  [26.99578094]
#  [26.95166016]
#  [26.86352539]
#  [26.99612427]
#  [26.94155312]
#  [26.91700554]
#  [26.96189308]
#  [26.97956276]
#  [26.94286537]
#  [26.95507812]
#  [26.94758034]
#  [26.95586395]
#  [26.96151352]
#  [26.94782257]
#  [26.89795494]
#  [26.89012527]
#  [26.884161  ]
#  [26.95955086]
#  [26.95038223]
#  [26.94423103]
#  [26.91855431]
#  [27.00579453]
#  [26.99666405]
#  [26.86738205]
#  [26.96947098]
#  [26.89926147]
#  [26.87329102]
#  [26.95981407]
#  [26.91686249]
#  [26.87485886]
#  [26.89434624]
#  [26.90838814]
#  [26.94562721]
#  [26.8630867 ]
#  [26.93157578]
#  [26.98425484]
#  [26.92675591]
#  [26.99658203]
#  [26.89994812]
#  [26.98305702]
#  [26.92616081]
#  [26.92582512]
#  [26.93564415]
#  [26.84617233]
#  [26.99460983]
#  [26.88523483]
#  [26.87221909]
#  [27.0095005 ]
#  [26.93132591]
#  [26.89858437]
#  [26.93463516]
#  [26.87177467]
#  [26.90240097]
#  [26.92614746]
#  [26.88911438]
#  [26.93989754]
#  [26.98280525]
#  [26.91507149]
#  [26.92059708]
#  [26.97741508]
#  [26.95988274]
#  [26.88861275]
#  [26.88682747]
#  [26.89583397]
#  [26.90530396]
#  [26.93771744]
#  [26.8799324 ]
#  [26.86276817]
#  [26.89671135]
#  [27.01053047]
#  [26.90409088]
#  [26.94617271]
#  [26.87413406]
#  [27.00228882]
#  [26.8770504 ]
#  [26.93925476]
#  [26.95456505]
#  [26.94222641]
#  [26.94242668]
#  [26.90989113]
#  [26.91069794]
#  [26.94875717]
#  [26.91777611]
#  [26.88660431]
#  [26.89137459]
#  [26.91521263]
#  [26.95782852]
#  [26.92390633]
#  [26.87781334]
#  [26.96419907]
#  [26.96206665]
#  [26.97367668]
#  [26.95572853]
#  [26.93593216]
#  [26.91425705]
#  [26.92735481]
#  [26.94742203]
#  [26.9922905 ]
#  [26.92602348]
#  [26.95234299]
#  [26.88230705]
#  [26.82454491]
#  [26.89998436]
#  [26.93371773]
#  [26.95165443]
#  [26.93975067]
#  [26.92320442]
#  [26.88578796]
#  [26.96646881]
#  [26.97963333]
#  [26.95953178]
#  [26.98802567]
#  [26.9164772 ]
#  [26.89799309]
#  [27.00226593]
#  [27.00253868]
#  [26.86635017]
#  [26.91512299]
#  [26.94398117]
#  [26.94792557]
#  [26.90006447]
#  [26.97149467]
#  [26.96482277]
#  [26.96603012]
#  [26.94044876]
#  [26.97158241]
#  [26.96395683]
#  [27.04002571]
#  [26.86550331]
#  [26.92428589]
#  [26.91526222]
#  [26.89644051]
#  [26.8799324 ]
#  [26.96141243]
#  [26.87202644]
#  [26.93655777]
#  [26.8658905 ]
#  [26.89821053]
#  [26.98403931]
#  [26.93571472]
#  [27.00165558]
#  [27.01468277]
#  [26.89248085]
#  [27.04805565]
#  [26.85477638]
#  [26.88585091]
#  [26.93088722]
#  [26.92355156]
#  [26.96264648]
#  [26.9227829 ]
#  [26.96612358]
#  [26.91693306]
#  [26.95525169]
#  [26.96962357]
#  [27.04489136]
#  [26.88922501]
#  [26.91275406]
#  [26.92315483]
#  [26.9773922 ]
#  [26.87438774]
#  [26.95914078]
#  [26.96871948]
#  [27.00411797]
#  [26.90469742]
#  [26.98368263]
#  [26.93981743]
#  [26.94129181]
#  [26.96161079]
#  [26.94365311]
#  [26.94358253]
#  [26.96554947]
#  [26.89833641]
#  [26.88896942]
#  [26.91292381]
#  [26.91073608]
#  [26.92687798]
#  [26.9621067 ]
#  [26.95101738]
#  [26.90361404]
#  [26.89488983]
#  [26.92513084]
#  [26.97359848]
#  [27.01153946]
#  [26.87553787]
#  [26.98051834]
#  [26.92623901]
#  [27.01341629]
#  [26.94525909]
#  [26.90861511]
#  [26.94387436]
#  [26.92126656]
#  [26.96066666]
#  [26.94452286]
#  [27.00489426]
#  [26.99176216]
#  [26.86512375]
#  [26.91022491]
#  [26.91971779]
#  [26.96993828]
#  [26.95148659]
#  [26.95121765]
#  [26.90405464]
#  [27.00562668]
#  [26.94949341]
#  [26.83966827]
#  [26.96596146]
#  [26.95553398]
#  [26.90848541]
#  [26.97167778]
#  [26.93657684]
#  [26.98391914]
#  [26.86291695]
#  [26.96493912]
#  [26.95956421]
#  [26.94154549]
#  [26.95900536]
#  [26.95026016]
#  [26.90244102]
#  [26.93713951]
#  [26.88309479]
#  [26.83943176]
#  [26.94015884]
#  [26.92662811]
#  [26.92686653]
#  [26.90289116]
#  [26.95151329]
#  [26.88737488]
#  [26.96001816]
#  [26.96847343]
#  [26.93547058]
#  [26.99491692]
#  [26.91908646]
#  [26.91356087]
#  [26.91029167]
#  [26.9485817 ]
#  [26.9429245 ]
#  [26.95301056]
#  [26.97132683]
#  [26.81799889]
#  [26.9217186 ]
#  [26.92731667]
#  [26.92776108]
#  [26.86787415]
#  [26.94768333]
#  [26.84168243]
#  [26.94070053]
#  [27.03067017]
#  [26.88259506]
#  [26.87381172]
#  [27.03240776]
#  [26.91057968]
#  [26.92388535]
#  [26.98600578]
#  [26.93212891]
#  [26.92129898]
#  [26.94475555]
#  [26.93128777]
#  [27.01130867]
#  [26.93483162]
#  [26.90628815]
#  [26.97258377]
#  [26.90374565]
#  [26.91737938]
#  [26.95134354]
#  [26.87380028]
#  [26.97790527]
#  [26.90864182]
#  [26.9516468 ]
#  [26.89065742]
#  [26.94156837]
#  [26.88053322]
#  [26.90052032]
#  [26.92185783]
#  [26.93955612]
#  [26.9453125 ]
#  [26.84477234]
#  [26.92810822]
#  [26.93726349]
#  [26.91262817]
#  [27.00973892]
#  [26.97223854]
#  [27.00117493]
#  [26.94062996]
#  [26.94089127]
#  [26.89865685]
#  [26.93338394]
#  [26.87830925]
#  [26.88493729]
#  [26.91525078]
#  [26.9460125 ]
#  [26.92476463]
#  [26.84378242]
#  [26.971138  ]
#  [26.9790535 ]
#  [26.91457176]
#  [26.89034081]
#  [26.92756653]
#  [26.95250702]
#  [26.91946793]
#  [27.04216003]
#  [26.95056915]
#  [26.98535919]
#  [26.88704491]
#  [26.97900391]
#  [26.95072746]
#  [26.90875053]
#  [26.95632553]
#  [26.91286278]
#  [26.822855  ]
#  [26.87992859]
#  [26.91917801]
#  [26.95556641]
#  [26.87706184]
#  [26.89658928]
#  [26.98432159]
#  [26.90288544]
#  [27.02377129]
#  [26.94743347]
#  [26.87975883]
#  [26.94785118]
#  [26.97205353]
#  [27.0124836 ]
#  [26.95321274]
#  [26.90952873]
#  [26.96426392]
#  [26.9323101 ]
#  [26.95453835]
#  [26.92500496]
#  [26.92731667]
#  [26.98736954]
#  [26.97958374]
#  [26.87339401]
#  [26.90660858]
#  [26.8927784 ]
#  [27.00619888]
#  [26.93854141]
#  [26.90112305]
#  [26.94021797]
#  [26.94568634]
#  [26.91536522]
#  [26.94305229]
#  [26.98211288]
#  [26.91009903]
#  [26.84274101]
#  [26.97075653]
#  [26.9316349 ]
#  [26.90839005]
#  [27.00076485]
#  [27.00750542]
#  [26.86946106]
#  [26.93953514]
#  [26.94456291]
#  [26.90506172]
#  [26.95490456]
#  [26.93694115]
#  [26.96890259]
#  [26.89830208]
#  [26.94880295]
#  [26.96412849]
#  [26.91874504]
#  [26.9454422 ]
#  [26.94124603]
#  [27.00045776]
#  [26.89885712]
#  [26.88763618]
#  [26.98893166]
#  [26.88612175]
#  [26.94710541]
#  [26.91630363]
#  [26.97795677]
#  [26.96909714]
#  [27.00432205]
#  [26.99567604]
#  [26.99316406]
#  [26.99776459]
#  [26.88916588]
#  [26.91687202]
#  [27.00618553]
#  [26.91102219]
#  [26.96339035]
#  [26.99242592]
#  [26.93266106]
#  [26.97538567]
#  [26.89670753]
#  [26.98288536]
#  [26.98323822]
#  [27.00074959]
#  [26.85053253]
#  [26.95783424]
#  [26.86692238]
#  [26.91566849]
#  [26.997509  ]
#  [26.92199135]
#  [26.97208405]
#  [26.96833038]
#  [26.98187637]
#  [26.88594818]
#  [26.85393524]
#  [26.94866562]
#  [26.8471756 ]
#  [26.91591263]
#  [26.9275074 ]
#  [26.95108986]
#  [26.8523159 ]
#  [26.86164284]
#  [26.92381477]
#  [26.94406128]
#  [26.87487221]
#  [26.98830795]
#  [26.92539597]
#  [26.96167564]
#  [26.89457512]
#  [26.93109322]
#  [26.98533058]
#  [26.907938  ]
#  [26.93868256]
#  [26.96130943]
#  [26.98058891]
#  [26.92113495]
#  [26.92816544]
#  [26.93935013]
#  [26.91851616]
#  [26.90934181]
#  [26.98768425]
#  [26.94415474]
#  [26.93289375]
#  [26.94009781]
#  [26.8822155 ]
#  [26.94756317]
#  [26.99043465]
#  [26.92783737]
#  [26.93194389]
#  [26.89269257]
#  [26.97549438]
#  [26.90001678]
#  [26.97258568]
#  [26.94210625]
#  [26.87697411]
#  [26.87960434]
#  [26.92209816]
#  [26.93539047]
#  [26.93432426]
#  [26.9577198 ]
#  [26.92983627]
#  [26.96871185]
#  [27.00732231]
#  [26.92478371]
#  [26.8774147 ]
#  [27.02190018]
#  [26.92935181]
#  [26.88949585]
#  [26.86857986]
#  [26.91691589]
#  [26.94402122]
#  [26.94702721]
#  [26.91585922]
#  [26.94178391]
#  [26.90288925]
#  [26.87002563]
#  [26.97742462]
#  [26.88811874]
#  [26.92373848]
#  [26.91520119]
#  [26.89692307]
#  [26.99283028]
#  [26.87512779]
#  [26.99074173]
#  [26.9527092 ]
#  [26.95428276]
#  [26.96909904]
#  [26.97419739]
#  [26.90580177]
#  [26.9566021 ]
#  [26.94799232]
#  [26.93361855]
#  [26.94467163]
#  [26.92594147]
#  [26.96842384]
#  [26.92578316]
#  [26.97843361]
#  [26.99122238]
#  [26.92423439]
#  [26.88457489]
#  [26.90365219]
#  [26.93439674]
#  [26.92622566]
#  [26.98223114]
#  [26.9158287 ]
#  [26.89335442]
#  [26.92504883]
#  [26.94342804]
#  [27.00835037]
#  [26.87514687]
#  [26.89489555]
#  [26.86482239]
#  [26.97988319]
#  [26.95226288]
#  [26.95038605]
#  [26.93040848]
#  [26.9386673 ]
#  [26.94787407]
#  [26.9660778 ]
#  [26.92573738]
#  [26.94295311]
#  [26.91991043]
#  [26.91999245]
#  [26.9752388 ]
#  [26.97739983]
#  [26.95059967]
#  [26.92824936]
#  [26.91079712]
#  [26.96985626]
#  [27.02064705]
#  [26.90434074]
#  [27.01962852]
#  [26.92947578]
#  [26.88442039]
#  [26.99673843]
#  [26.93524933]
#  [26.93932343]
#  [26.98599625]
#  [26.89255142]
#  [26.90605545]
#  [26.94886017]
#  [26.97637749]
#  [26.96829414]
#  [26.94891548]
#  [27.01703644]
#  [26.93182564]
#  [26.94610977]
#  [26.915411  ]
#  [26.98001862]
#  [26.8853054 ]
#  [26.94958687]
#  [26.86114311]
#  [26.86159897]
#  [27.01309586]
#  [26.83975601]
#  [26.99925041]
#  [26.93699074]
#  [26.9056263 ]
#  [26.90047836]
#  [26.98311996]
#  [26.93526459]
#  [26.90623665]
#  [26.92891121]
#  [26.88446808]
#  [27.02251816]
#  [26.9553051 ]
#  [26.91061783]
#  [27.00835228]
#  [26.92994308]
#  [26.95708084]
#  [26.94159889]
#  [26.92866135]
#  [27.00556374]
#  [26.98300743]
#  [26.91871834]
#  [26.95000076]
#  [26.99244881]
#  [26.91754532]
#  [26.94706535]
#  [26.93406868]
#  [26.95331001]
#  [26.9373436 ]
#  [26.93061447]
#  [26.86351395]
#  [26.97101784]
#  [26.94491196]
#  [26.87830734]
#  [26.89846992]
#  [26.87828827]
#  [26.86108971]
#  [26.99800301]
#  [26.95940208]
#  [26.96630669]
#  [26.90532303]
#  [26.92523575]
#  [26.88973045]
#  [26.92256355]
#  [26.90646935]
#  [26.97827148]
#  [26.94777489]
#  [26.96249962]
#  [26.97687531]
#  [26.88319206]
#  [26.93320656]
#  [26.93824959]
#  [26.95781326]
#  [26.87360382]
#  [26.9465313 ]
#  [26.94275093]
#  [26.90276909]
#  [26.9974041 ]
#  [26.88229179]
#  [26.8877964 ]
#  [26.9303875 ]
#  [26.95646477]
#  [27.00315285]
#  [26.89645767]
#  [26.93656921]
#  [26.92248726]
#  [26.97514343]
#  [26.8753643 ]
#  [26.94796371]
#  [26.86246109]
#  [26.95055962]
#  [27.00946808]
#  [26.96936226]
#  [26.99052238]
#  [26.96679878]
#  [26.93085861]
#  [26.92782402]
#  [26.91322708]
#  [26.91916847]
#  [26.87955666]
#  [26.91363907]
#  [26.90875626]
#  [26.98443985]
#  [26.90446472]
#  [26.89645195]
#  [26.91838455]
#  [26.88409615]
#  [26.95561218]
#  [26.90291405]
#  [26.93995285]
#  [26.95658112]
#  [26.95733833]
#  [26.98435783]
#  [27.02245522]
#  [26.89156151]
#  [26.98508835]
#  [26.87603569]
#  [26.86298561]
#  [26.90692902]
#  [26.94922066]
#  [26.92537117]
#  [26.92939758]
#  [27.03515053]
#  [26.83090782]
#  [26.89047241]
#  [26.92606926]
#  [26.92970657]
#  [26.95277214]
#  [27.00981903]
#  [26.95174217]
#  [26.91486549]
#  [26.92070389]
#  [26.97303009]
#  [26.92346954]
#  [26.88463783]
#  [26.88102531]
#  [26.89888   ]
#  [26.90331459]
#  [26.94290161]
#  [26.89533424]
#  [26.94856262]
#  [26.85627174]
#  [26.96488762]
#  [26.94523048]
#  [26.96925163]
#  [26.8893261 ]
#  [26.83850861]
#  [26.88952827]
#  [26.94101524]
#  [26.95029831]
#  [26.93557167]
#  [26.93959618]
#  [26.94496536]
#  [26.93184662]
#  [26.83607292]
#  [26.94881821]
#  [26.93237495]
#  [26.97888947]
#  [26.91750717]
#  [26.89765549]
#  [26.90257072]
#  [26.9278698 ]
#  [26.86800385]
#  [27.05475998]
#  [26.91764259]
#  [26.91432381]
#  [26.98920059]
#  [26.92565346]
#  [26.87167931]
#  [26.89653015]
#  [26.92781258]
#  [26.94534683]
#  [26.99144363]
#  [26.96925926]
#  [26.98404121]
#  [26.93310547]
#  [26.97808456]
#  [26.93849373]
#  [26.8919487 ]
#  [26.93696785]
#  [26.99356842]
#  [26.95478058]
#  [26.97361946]
#  [26.87335396]
#  [26.79632378]
#  [26.84926224]
#  [26.87777519]
#  [26.88766289]
#  [26.87478828]
#  [26.95834732]
#  [26.95750809]
#  [26.97580338]
#  [26.8931675 ]
#  [26.95721626]
#  [26.92920113]
#  [27.01320457]
#  [26.9902916 ]
#  [26.93187904]
#  [26.95210457]
#  [26.99721718]
#  [26.90509796]
#  [27.03490067]
#  [26.89945984]
#  [26.98443413]
#  [26.91762924]
#  [26.92406082]
#  [26.92030716]
#  [26.91076469]
#  [26.98599625]
#  [26.90136528]
#  [27.00731277]
#  [26.91443062]
#  [26.94509315]
#  [26.93523788]
#  [26.93760872]
#  [26.90892982]
#  [26.99197769]
#  [26.90496063]
#  [26.94135284]
#  [26.91530037]
#  [26.90848541]
#  [26.93982506]
#  [26.92419624]
#  [26.92634583]
#  [26.91201973]
#  [26.93665886]
#  [26.91663933]
#  [26.95797729]
#  [26.89593315]
#  [26.90040207]
#  [26.88838959]
#  [26.93806648]
#  [26.94467163]
#  [26.9471302 ]
#  [26.90067482]
#  [27.01633072]
#  [26.96320534]
#  [26.94104195]
#  [26.99068451]
#  [26.93374634]
#  [26.91826248]
#  [26.91932487]
#  [27.01191902]
#  [26.91942596]
#  [26.99988937]
#  [26.93900871]
#  [26.96686745]
#  [26.91905975]
#  [26.91797066]
#  [26.89551926]
#  [26.92894936]
#  [27.00271225]
#  [26.97359467]
#  [26.82957268]
#  [26.92800522]
#  [26.88103294]
#  [26.90620613]
#  [26.94779778]
#  [26.92937279]
#  [26.96865845]
#  [26.92603683]
#  [26.89949036]
#  [26.92045975]
#  [26.9077549 ]
#  [26.91750145]
#  [27.02234459]
#  [26.88738251]
#  [26.9726181 ]
#  [26.91317558]
#  [26.93717194]
#  [26.96043777]
#  [26.93481255]
#  [26.97504044]
#  [26.95804024]
#  [26.93608856]
#  [26.95024681]
#  [26.97002411]
#  [26.9447422 ]
#  [26.87852097]
#  [26.94840431]
#  [26.92035103]
#  [27.03594208]
#  [26.91586876]
#  [26.92077446]
#  [26.92168427]
#  [26.99187469]
#  [26.93226433]
#  [26.97228432]
#  [27.04326439]
#  [26.9061203 ]
#  [26.99515533]
#  [27.00984955]
#  [26.86475182]
#  [26.92406082]
#  [26.93548203]
#  [26.99384308]
#  [26.960495  ]
#  [26.87016869]
#  [26.94721603]
#  [26.93791771]
#  [26.99202538]
#  [26.97956276]
#  [26.92107773]
#  [26.96451759]
#  [26.86841393]
#  [26.90846443]
#  [26.91458321]
#  [26.92335701]
#  [26.96082687]
#  [26.87354279]
#  [26.94741821]
#  [26.92074394]
#  [26.92619324]
#  [26.90442657]
#  [27.033638  ]
#  [26.94182396]
#  [26.9760685 ]
#  [26.97028542]
#  [27.01605415]
#  [26.95768547]
#  [26.99714661]
#  [26.98106575]
#  [26.94558144]
#  [26.94438553]
#  [26.97520256]
#  [26.96685028]
#  [26.96398735]
#  [26.89543152]
#  [26.95832443]
#  [26.95593834]
#  [26.93385887]
#  [27.01791382]
#  [26.93381691]
#  [27.00960922]
#  [27.01763535]
#  [26.96941757]
#  [26.85292435]
#  [26.93360519]
#  [27.01870918]
#  [26.94657898]
#  [26.95403671]
#  [26.88655663]
#  [26.90305901]
#  [26.98552513]
#  [26.9427681 ]]

# %% [markdown]
# **PLOTTING THE HISTOGRAM FOR NEWLY GENERATED 1000 VALUES**

# %%
import matplotlib.pyplot as plt
mean_total = np.mean(areal_mean)
max = np.nanmax(num_data)                              # FINDING THE MAXIMUM VALUE OF MEAN VALUE
bin_edges = np.arange(26.75,max,0.01)                  # DEFINING THE BIN EDGES 
plt.hist(num_data,bins = bin_edges,edgecolor='Black')
plt.axvline(mean_total,color='red')
plt.title('Histogram of SST')
plt.xlabel('Value of SST')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **CALCULATING THE CONFIDENCE INTERVAL AT 95 % USING Z TEST**

# %%
from scipy.stats import norm
#For calculating deviation

devi = np.std(areal_mean)
a1 = devi.values
print("The standard deviation for the sample is",a1)

#For calculating Sample mean
samp_mean = np.mean(num_data)
print("The mean of the sample is",samp_mean)

#For z-value for the 95% confidence interval
cf = 0.025
z_val = norm.ppf(cf)
print("The Z-value for 95 % confidence interval is",z_val)

# For calculating confidence intervals
lb = samp_mean-(-z_val*a1)/np.sqrt(1000)

ub = samp_mean+(-z_val*a1)/np.sqrt(1000)
print('The 95% confidence interval for the given sample is',{ lb , ub})
# Out:
# The standard deviation for the sample is 0.8956066966056824
# The mean of the sample is 26.935919637680055
# The Z-value for 95 % confidence interval is -1.9599639845400545
# The 95% confidence interval for the given sample is {26.880410379534563, 26.991428895825546}

# %% [markdown]
# **PLOTTING THE HISTOGRAM WITH UPPER AND LOWER BOUND OF CONFIDENCE INTERVAL**

# %%
import matplotlib.pyplot as plt
mean_total = np.mean(areal_mean)
max = np.nanmax(num_data)                              # FINDING THE MAXIMUM VALUE OF MEAN VALUE
bin_edges = np.arange(26.75,max,0.01)                  # DEFINING THE BIN EDGES 
plt.hist(num_data,bins = bin_edges,edgecolor='Black')
plt.axvline(mean_total,color='red',label='Population mean')
plt.axvline(lb,color='green',label='Lower bound',linestyle='dashed')
plt.axvline(ub,color='green',label='Upper bound',linestyle='dashed')
plt.legend(loc='upper left')
plt.title('Histogram of SST')
plt.xlabel('Value of SST')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **CALCULATING THE 95 % CONFIDENCE INTERVAL USING T TEST**

# %%
#For calculating the confidence interval using  T distribution
from scipy import stats
n = len(num_data)

#For calculating the sample standard deviation 
'''
num_data = np.zeros([a,1])         #Creating an array using np.zeros 
for i in range(a):
    rand_steps = np.random.choice(areal_mean,360,replace=False)             # PICKING UP RANDOM 360 NON REPEATING STEPS OUT OF TOTAL 1868 STEPS
    num_data[i] = np.std(rand_steps)                                       # STORING THESE VALUES INTO THE ALREADY CREATED EMPTY ARRAY
'''                     
sq_mean = (areal_mean - samp_mean)**2
mean_2 = np.sum(sq_mean)/(len(num_data)-1)
t_dev = np.sqrt(mean_2)
print('The  Sx* value of the T value is',t_dev.values)
#For determining the t value
t_val = stats.t.ppf(1-cf,df=n-1)
print('The value of T for 95% confidence interval is',t_val)

#For determining the lower and upper bound 
ts=(t_val*t_dev)/np.sqrt(len(num_data))
lb2 = samp_mean-(t_val*t_dev)/np.sqrt(len(num_data))
ub2 = samp_mean+(t_val*t_dev)/np.sqrt(len(num_data))
print('The 95 % confidence interval using T distribution is',lb2.values,ub2.values)
# Out:
# The  Sx* value of the T value is 1.22468440942307
# The value of T for 95% confidence interval is 1.9623414611334487
# The 95 % confidence interval using T distribution is 26.859922231643083 27.011917043717027

# %% [markdown]
# **PLOTTING THE HISTOGRAM WITH LOWER AND UPPER BOUND OF T TEST**

# %%
import matplotlib.pyplot as plt
mean_total = np.mean(areal_mean)
max = np.nanmax(num_data)                              # FINDING THE MAXIMUM VALUE OF MEAN VALUE
bin_edges = np.arange(26.75,max,0.01)                  # DEFINING THE BIN EDGES 
plt.hist(num_data,bin_edges,edgecolor='Black')
plt.axvline(mean_total,color='red',label='Population mean')
plt.axvline(lb,color='cyan',label='Lower bound Z distribution',linestyle='dashed')
plt.axvline(ub,color='cyan',label='Upper bound Z distribution',linestyle='dashed')
plt.axvline(lb2,color='green',label='Lower bound T test',linestyle='dashed')
plt.axvline(ub2,color='green',label='Upper bound T test',linestyle='dashed')
plt.legend(loc='upper left')
plt.title('Histogram of T distribution')
plt.xlabel('Value of SST')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **HYPOTHESIS TESTING USING THE Z TEST**

# %%
# Hypothesis testing using z-test
from statsmodels.stats.weightstats import ztest
z_stat, p_value = ztest(num_data,value = mean_total.values)
print('Z-Statistic:', z_stat)
print('P-Value:', p_value)
alpha = 0.05
if p_value < alpha:                                      # H0 = NULL HYPOTHESIS ( Mu = Mu0)
    print("Reject the null hypothesis")
else:                                                   # H1 = ALTERNATE HYPOTHESIS(Mu ~= Mu0)
    print("Fail to reject the null hypothesis")
# Out:
# Z-Statistic: [-1.55980574]
# P-Value: [0.1188058]
# Fail to reject the null hypothesis

# %% [markdown]
# **HYPOTHESIS TESTING USING T TEST**

# %%
#Hypothesis testing using t-test
from scipy.stats import ttest_1samp
t_stat, p_value = ttest_1samp(num_data, mean_total.values)
print('T-Statistic:', t_stat)
print('P-Value:', p_value)
alpha = 0.05
if p_value < alpha:                                      # H0 = NULL HYPOTHESIS ( Mu = Mu0)
    print("Reject the null hypothesis")                  
else:                                                    # H1 = ALTERNATE HYPOTHESIS(Mu ~= Mu0)
    print("Fail to reject the null hypothesis")
# Out:
# T-Statistic: [-1.55980574]
# P-Value: [0.11912251]
# Fail to reject the null hypothesis

# %% [markdown]
# **HYPOTHESIS TESTING USING T TEST FOR TWO SAMPLES (1901-1930) & (1995-2024)**

# %%
from scipy.stats import ttest_ind
import numpy as np

SST = ds['sst']
T1 = areal_mean.sel(time =slice('1901-01-01','1930-12-31'))
T2 = areal_mean.sel(time =slice('1995-01-01','2024-12-31'))

t_stat, p_value = ttest_ind(T1.values, T2.values)
print('T statistic' , t_stat)
print('P value',p_value)
alpha = 0.05
if p_value < alpha:                                                             # H0 = NULL HYPOTHESIS ( Mu1 = Mu2)
    print("The means of the two samples are significantly different.")
else:                                                                          # H1 = ALTERNATE HYPOTHESIS(Mu1 ~= Mu2)
    print("No significant difference between the two sample means.")
# Out:
# T statistic -0.021652844206664554
# P value 0.9827308956587996
# No significant difference between the two sample means.

# %% [markdown]
# **HYPOTHESIS TESTING USING F TEST**

# %%
from scipy.stats import f

var1 = np.var(T1,ddof=1)
var2 = np.var(T2,ddof=1)
f_stat = var2/var1
df1 = len(T1)-1
df2= len(T2)-1
p_value = f.sf(f_stat, df2, df1)
print('F statistic',f_stat.values)
print('P value' , p_value)
alpha = 0.05
if p_value < alpha:
    print("The variances of the two samples are significantly different.")
else:
    print("No significant difference between the two sample variances.")
# Out:
# F statistic 1.6351866135840347
# P value 1.8075664052345043e-06
# The variances of the two samples are significantly different.

# %%
print(var1.values)
print(var2.values)
# Out:
# 0.6203606128692627
# 1.014405369758606
